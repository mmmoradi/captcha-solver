# %% [markdown]
# # Captcha Downloader

# %% [markdown]
# Max number of captcha: 99999
#
# First goal: 1000 captchas
#
# formant: `NNNNN-CCCCC.gif`
#
# - N: number
# - C: CAPTCHA code

# %%
import os
import re
import time
import requests
from PIL import Image
from io import BytesIO


dataset_dir = "dataset/captchas"

os.makedirs(dataset_dir, exist_ok=True)
# os.chdir(dataset_dir)


urls = ["https://ems1.sbu.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    "https://golestan.iust.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    # "https://golestan.ikiu.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    "https://osreg.pnu.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    "https://education.cfu.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    "https://golestan.ui.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    "https://ems.atu.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    "https://edu.qom.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    "https://golestan.uok.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    "https://golestan.yazd.ac.ir/Forms/AuthenticateUser/captcha.aspx",
    "https://golestan.uok.ac.ir/Forms/AuthenticateUser/captcha.aspx"]


def get_last_captcha_number():
    existing_files = [f for f in os.listdir(dataset_dir) if re.match(r"(\d{5})-([A-Za-z0-9]+)\.gif", f)]
    numbers = [int(re.match(r"(\d{5})-", f).group(1)) for f in existing_files if re.match(r"(\d{5})-", f)]
    return max(numbers) if numbers else 0

def download_captcha(url):
    response = requests.get(url)
    if response.status_code == 200:
        return Image.open(BytesIO(response.content))
    else:
        print("Failed to download captcha.")
        return None


def main():
    counter = get_last_captcha_number() + 1
    
    while True:
        url = urls[counter % len(urls)]
        
        img = download_captcha(url)
        if img is None:
            break

        img.show()
        captcha_code = input("Code: ").strip()
        if captcha_code.lower() == 'q':
            break
        
        filename = f"{counter:05d}-{captcha_code}.gif"
        img.save(os.path.join(dataset_dir, filename))
        print(f"Saved: {filename}")
        print()
        counter += 1


if __name__ == "__main__":
    main()
    print("Done!")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  3PKfW
# Saved: 00101-3PKfW.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  3WyYv
# Saved: 00102-3WyYv.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  pFNaR
# Saved: 00103-pFNaR.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  SsZNU
# Saved: 00104-SsZNU.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  KBa4g
# Saved: 00105-KBa4g.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  EDnsb
# Saved: 00106-EDnsb.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  a63W3
# Saved: 00107-a63W3.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  FcXUm
# Saved: 00108-FcXUm.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  WA8GV
# Saved: 00109-WA8GV.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  vmPtn
# Saved: 00110-vmPtn.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  FubsQ
# Saved: 00111-FubsQ.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  4GwYU
# Saved: 00112-4GwYU.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  YNTXC
# Saved: 00113-YNTXC.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  ynsTk
# Saved: 00114-ynsTk.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  y82Yt
# Saved: 00115-y82Yt.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  SatQB
# Saved: 00116-SatQB.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  xySKT
# Saved: 00117-xySKT.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  5NHAg
# Saved: 00118-5NHAg.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  vT4ec
# Saved: 00119-vT4ec.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  AVKsS
# Saved: 00120-AVKsS.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  Gw2Vg
# Saved: 00121-Gw2Vg.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  mNkwG
# Saved: 00122-mNkwG.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  CV9yR
# Saved: 00123-CV9yR.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  4D8D9
# Saved: 00124-4D8D9.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  qExch
# Saved: 00125-qExch.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  UTegV
# Saved: 00126-UTegV.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  yQqTM
# Saved: 00127-yQqTM.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  5kXWD
# Saved: 00128-5kXWD.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  mfp6Q
# Saved: 00129-mfp6Q.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  qx62X
# Saved: 00130-qx62X.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  MVEAA
# Saved: 00131-MVEAA.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  MWtHM
# Saved: 00132-MWtHM.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  3yVXx
# Saved: 00133-3yVXx.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  Pkg3q
# Saved: 00134-Pkg3q.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code:  NKcBF
# Saved: 00135-NKcBF.gif
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=140x50>
# Code: